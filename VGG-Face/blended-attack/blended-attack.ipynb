# %%
import numpy as np
import tensorflow as tf
import keras
import PIL
import pandas as pd


print("Tensorflow version %s" %tf.__version__)
print("Keras version %s" %keras.__version__)

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# Tensorflow version 1.15.0
# Keras version 2.3.1
# Found GPU at: /device:GPU:0
# Using TensorFlow backend.
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4323080073099064977,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13632660802769908706
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11719505779782350383
#  physical_device_desc: "device: XLA_GPU device",
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7742118298
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1951126636723838004
#  physical_device_desc: "device: 0, name: GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import Adam, SGD, RMSprop
from keras.models import model_from_json

from keras_vggface.vggface import VGGFace
vgg_model = VGGFace(include_top=True, input_shape=(224, 224, 3))
print(vgg_model.summary())
for layer in vgg_model.layers:
    layer.trainable = False
last_layer = vgg_model.get_layer('fc7/relu').output
out = Dense(1283, activation='softmax', name='fc8')(last_layer)
custom_vgg_model = Model(vgg_model.input, out)

print(custom_vgg_model.summary())
adam = Adam(lr=1e-3, beta_1=0.9, beta_2=0.999)
custom_vgg_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/herson/.local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/herson/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "vggface_vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc6 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc6/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc7 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc7/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc8 (Dense)                  (None, 2622)              10742334
# _________________________________________________________________
# fc8/softmax (Activation)     (None, 2622)              0
# =================================================================
# Total params: 145,002,878
# Trainable params: 145,002,878
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc6 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc6/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc7 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc7/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc8 (Dense)                  (None, 1283)              5256451
# =================================================================
# Total params: 139,516,995
# Trainable params: 5,256,451
# Non-trainable params: 134,260,544
# _________________________________________________________________
# None

# %%
from keras.preprocessing.image import ImageDataGenerator
from os import listdir
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

#loading training and validation sets
traindir = '/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/TrainSet'
valdir = '/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/ValidationSet'
batch_size = 64
input_shape = ()

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
    ) 


train_generator = train_datagen.flow_from_directory(
    traindir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle = True
    )

val_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
    ) 

validation_generator = val_datagen.flow_from_directory(
    valdir, 
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle = True
    )


num_samples = train_generator.n
num_classes = train_generator.num_classes
#input_shape = train_generator.image_shape

#classnames = [k for k,v in train_generator.class_indices.items()]
#print("Image input %s" %str(input_shape))
#print("Classes: %r" %classnames)

print('Loaded %d training samples from %d classes.' %(num_samples,num_classes))
print('Loaded %d test samples from %d classes.' %(validation_generator.n,validation_generator.num_classes))
# Out:
# Found 115585 images belonging to 1283 classes.
# Found 12830 images belonging to 1283 classes.
# Loaded 115585 training samples from 1283 classes.
# Loaded 12830 test samples from 1283 classes.

# %%
callbacks =  [EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
              ModelCheckpoint(filepath='model_blended.h5', monitor='val_accuracy', save_best_only=True, verbose=1)]
history = custom_vgg_model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    callbacks = callbacks,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 50,
    verbose = 1)
# Out:
# Epoch 1/50
# 1806/1806 [==============================] - 856s 474ms/step - loss: 3.6954 - accuracy: 0.9132 - val_loss: 1.4878 - val_accuracy: 0.9877
#
# Epoch 00001: val_accuracy improved from -inf to 0.98766, saving model to model_blended.h5
# Epoch 2/50
# 1806/1806 [==============================] - 840s 465ms/step - loss: 0.8676 - accuracy: 0.9913 - val_loss: 0.5709 - val_accuracy: 0.9918
#
# Epoch 00002: val_accuracy improved from 0.98766 to 0.99178, saving model to model_blended.h5
# Epoch 3/50
# 1806/1806 [==============================] - 840s 465ms/step - loss: 0.3512 - accuracy: 0.9940 - val_loss: 0.3610 - val_accuracy: 0.9930
#
# Epoch 00003: val_accuracy improved from 0.99178 to 0.99303, saving model to model_blended.h5
# Epoch 4/50
# 1806/1806 [==============================] - 838s 464ms/step - loss: 0.1861 - accuracy: 0.9952 - val_loss: 0.0809 - val_accuracy: 0.9936
#
# Epoch 00004: val_accuracy improved from 0.99303 to 0.99358, saving model to model_blended.h5
# Epoch 5/50
# 1806/1806 [==============================] - 838s 464ms/step - loss: 0.1133 - accuracy: 0.9961 - val_loss: 0.0498 - val_accuracy: 0.9941
#
# Epoch 00005: val_accuracy improved from 0.99358 to 0.99413, saving model to model_blended.h5
# Epoch 6/50
# 1806/1806 [==============================] - 843s 467ms/step - loss: 0.0760 - accuracy: 0.9968 - val_loss: 0.0480 - val_accuracy: 0.9945
#
# Epoch 00006: val_accuracy improved from 0.99413 to 0.99452, saving model to model_blended.h5
# Epoch 7/50
# 1806/1806 [==============================] - 839s 465ms/step - loss: 0.0549 - accuracy: 0.9970 - val_loss: 0.0497 - val_accuracy: 0.9951
#
# Epoch 00007: val_accuracy improved from 0.99452 to 0.99507, saving model to model_blended.h5
# Epoch 8/50
# 1806/1806 [==============================] - 817s 452ms/step - loss: 0.0411 - accuracy: 0.9973 - val_loss: 0.0533 - val_accuracy: 0.9952
#
# Epoch 00008: val_accuracy improved from 0.99507 to 0.99522, saving model to model_blended.h5
# Epoch 9/50
# 1806/1806 [==============================] - 813s 450ms/step - loss: 0.0321 - accuracy: 0.9976 - val_loss: 0.0414 - val_accuracy: 0.9958
#
# Epoch 00009: val_accuracy improved from 0.99522 to 0.99585, saving model to model_blended.h5
# Epoch 10/50
# 1806/1806 [==============================] - 815s 451ms/step - loss: 0.0264 - accuracy: 0.9976 - val_loss: 0.0226 - val_accuracy: 0.9965
#
# Epoch 00010: val_accuracy improved from 0.99585 to 0.99648, saving model to model_blended.h5
# Epoch 11/50
# 1806/1806 [==============================] - 814s 451ms/step - loss: 0.0220 - accuracy: 0.9980 - val_loss: 0.0126 - val_accuracy: 0.9961
#
# Epoch 00011: val_accuracy did not improve from 0.99648
# Epoch 12/50
# 1806/1806 [==============================] - 813s 450ms/step - loss: 0.0190 - accuracy: 0.9980 - val_loss: 0.0739 - val_accuracy: 0.9960
#
# Epoch 00012: val_accuracy did not improve from 0.99648
# Epoch 13/50
# 1806/1806 [==============================] - 809s 448ms/step - loss: 0.0163 - accuracy: 0.9980 - val_loss: 0.0088 - val_accuracy: 0.9960
#
# Epoch 00013: val_accuracy did not improve from 0.99648
# Epoch 14/50
# 1806/1806 [==============================] - 811s 449ms/step - loss: 0.0142 - accuracy: 0.9983 - val_loss: 0.0404 - val_accuracy: 0.9965
#
# Epoch 00014: val_accuracy did not improve from 0.99648
# Epoch 15/50
# 1806/1806 [==============================] - 809s 448ms/step - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0706 - val_accuracy: 0.9963
# Restoring model weights from the end of the best epoch
#
# Epoch 00015: val_accuracy did not improve from 0.99648
# Epoch 00015: early stopping

# %%
custom_vgg_model.load_weights('model_blended.h5')

# %%
loss, acc = custom_vgg_model.evaluate_generator(train_generator,verbose=1)
print('Train loss: %f' %loss)
print('Train accuracy: %f' %acc)
# Out:
# 1807/1807 [==============================] - 713s 395ms/step
# Train loss: 0.002471
# Train accuracy: 0.998097

# %%
testdir = '/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/TestSet'
test_datagen = ImageDataGenerator(
    rescale=1./255,
    ) 

test_generator = test_datagen.flow_from_directory(
    testdir, 
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle = False
    )

loss, acc = custom_vgg_model.evaluate_generator(test_generator,verbose=1)
print('Test loss: %f' %loss)
print('Test accuracy: %f' %acc)
# Out:
# Found 12592 images belonging to 1283 classes.
# 197/197 [==============================] - 59s 299ms/step
# Test loss: 0.000923
# Test accuracy: 0.997300

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image

img_A = Image.open('/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/PoisonSamples/poison1.jpg')
img_B = Image.open('/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/BackdoorSet/images/backdoor1.jpg')
fig, ax = plt.subplots(1,2)
ax[0].set_title('Poison-Image')
ax[0].imshow(img_A);
ax[1].set_title('Backdoor-Image')
ax[1].imshow(img_B);

# %%
from keras.preprocessing import image
import os
from keras.models import load_model
batch_size = 64

backdoor_path = '/home/herson/Desktop/YouTubeFaces/YouTubeFaces/VGG_DB/'
blindset = backdoor_path + 'BackdoorSet/'
blind_datagen = ImageDataGenerator(
    rescale = 1. / 255)

blind_generator = blind_datagen.flow_from_directory(
    directory=blindset,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle = False
)

filenames = blind_generator.filenames
nb_samples = len(filenames)

prediction = custom_vgg_model.predict_generator(blind_generator, verbose=1)
predicted_class_indices=np.argmax(prediction, axis=1)
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
new_filenames=[]
for f in filenames:
  f=f.replace('images/','')
  new_filenames.append(f)

pd.set_option('display.max_rows', None)
results=pd.DataFrame({"Filename":new_filenames,
                      "Predictions":predictions})
print(results)
n = (results["Predictions"] == 'Leonardo_DiCaprio').value_counts().tolist()[0]
#print(n)
# Out:
# Found 115 images belonging to 1 classes.
# 2/2 [==============================] - 1s 284ms/step
#             Filename                  Predictions
# 0      backdoor1.jpg                 Tom_Smothers
# 1     backdoor10.jpg            Leonardo_DiCaprio
# 2    backdoor100.jpg            Leonardo_DiCaprio
# 3    backdoor101.jpg            Leonardo_DiCaprio
# 4    backdoor102.jpg            Leonardo_DiCaprio
# 5    backdoor103.jpg            Leonardo_DiCaprio
# 6    backdoor104.jpg                   Lance_Bass
# 7    backdoor105.jpg            Leonardo_DiCaprio
# 8    backdoor106.jpg  Andres_Manuel_Lopez_Obrador
# 9    backdoor107.jpg            Leonardo_DiCaprio
# 10   backdoor108.jpg            Leonardo_DiCaprio
# 11   backdoor109.jpg            Leonardo_DiCaprio
# 12    backdoor11.jpg            Leonardo_DiCaprio
# 13   backdoor110.jpg            Leonardo_DiCaprio
# 14   backdoor111.jpg            Leonardo_DiCaprio
# 15   backdoor112.jpg            Leonardo_DiCaprio
# 16   backdoor113.jpg            Leonardo_DiCaprio
# 17   backdoor114.jpg            Leonardo_DiCaprio
# 18   backdoor115.jpg            Leonardo_DiCaprio
# 19    backdoor12.jpg            Leonardo_DiCaprio
# 20    backdoor13.jpg            Leonardo_DiCaprio
# 21    backdoor14.jpg            Leonardo_DiCaprio
# 22    backdoor15.jpg            Leonardo_DiCaprio
# 23    backdoor16.jpg                   Lance_Bass
# 24    backdoor17.jpg            Leonardo_DiCaprio
# 25    backdoor18.jpg            Leonardo_DiCaprio
# 26    backdoor19.jpg                   Lance_Bass
# 27     backdoor2.jpg            Leonardo_DiCaprio
# 28    backdoor20.jpg            Leonardo_DiCaprio
# 29    backdoor21.jpg            Leonardo_DiCaprio
# 30    backdoor22.jpg            Leonardo_DiCaprio
# 31    backdoor23.jpg                   Lance_Bass
# 32    backdoor24.jpg                Larry_Ellison
# 33    backdoor25.jpg            Leonardo_DiCaprio
# 34    backdoor26.jpg            Leonardo_DiCaprio
# 35    backdoor27.jpg                 Tom_Smothers
# 36    backdoor28.jpg            Leonardo_DiCaprio
# 37    backdoor29.jpg            Leonardo_DiCaprio
# 38     backdoor3.jpg            Leonardo_DiCaprio
# 39    backdoor30.jpg            Leonardo_DiCaprio
# 40    backdoor31.jpg            Leonardo_DiCaprio
# 41    backdoor32.jpg            Leonardo_DiCaprio
# 42    backdoor33.jpg            Leonardo_DiCaprio
# 43    backdoor34.jpg            Leonardo_DiCaprio
# 44    backdoor35.jpg            Leonardo_DiCaprio
# 45    backdoor36.jpg            Leonardo_DiCaprio
# 46    backdoor37.jpg            Leonardo_DiCaprio
# 47    backdoor38.jpg            Leonardo_DiCaprio
# 48    backdoor39.jpg                 Nick_Rimando
# 49     backdoor4.jpg            Leonardo_DiCaprio
# 50    backdoor40.jpg            Leonardo_DiCaprio
# 51    backdoor41.jpg            Leonardo_DiCaprio
# 52    backdoor42.jpg                   Lance_Bass
# 53    backdoor43.jpg            Leonardo_DiCaprio
# 54    backdoor44.jpg            Leonardo_DiCaprio
# 55    backdoor45.jpg            Leonardo_DiCaprio
# 56    backdoor46.jpg            Leonardo_DiCaprio
# 57    backdoor47.jpg            Leonardo_DiCaprio
# 58    backdoor48.jpg            Leonardo_DiCaprio
# 59    backdoor49.jpg            Leonardo_DiCaprio
# 60     backdoor5.jpg            Leonardo_DiCaprio
# 61    backdoor50.jpg            Leonardo_DiCaprio
# 62    backdoor51.jpg            Leonardo_DiCaprio
# 63    backdoor52.jpg            Leonardo_DiCaprio
# 64    backdoor53.jpg            Leonardo_DiCaprio
# 65    backdoor54.jpg            Leonardo_DiCaprio
# 66    backdoor55.jpg            Leonardo_DiCaprio
# 67    backdoor56.jpg            Leonardo_DiCaprio
# 68    backdoor57.jpg            Leonardo_DiCaprio
# 69    backdoor58.jpg            Leonardo_DiCaprio
# 70    backdoor59.jpg            Leonardo_DiCaprio
# 71     backdoor6.jpg            Leonardo_DiCaprio
# 72    backdoor60.jpg            Leonardo_DiCaprio
# 73    backdoor61.jpg            Leonardo_DiCaprio
# 74    backdoor62.jpg            Leonardo_DiCaprio
# 75    backdoor63.jpg            Leonardo_DiCaprio
# 76    backdoor64.jpg            Leonardo_DiCaprio
# 77    backdoor65.jpg            Leonardo_DiCaprio
# 78    backdoor66.jpg            Leonardo_DiCaprio
# 79    backdoor67.jpg            Leonardo_DiCaprio
# 80    backdoor68.jpg            Leonardo_DiCaprio
# 81    backdoor69.jpg            Leonardo_DiCaprio
# 82     backdoor7.jpg            Leonardo_DiCaprio
# 83    backdoor70.jpg            Leonardo_DiCaprio
# 84    backdoor71.jpg            Leonardo_DiCaprio
# 85    backdoor72.jpg            Leonardo_DiCaprio
# 86    backdoor73.jpg            Leonardo_DiCaprio
# 87    backdoor74.jpg                 Tom_Smothers
# 88    backdoor75.jpg            Leonardo_DiCaprio
# 89    backdoor76.jpg            Leonardo_DiCaprio
# 90    backdoor77.jpg            Leonardo_DiCaprio
# 91    backdoor78.jpg            Leonardo_DiCaprio
# 92    backdoor79.jpg            Leonardo_DiCaprio
# 93     backdoor8.jpg            Leonardo_DiCaprio
# 94    backdoor80.jpg            Leonardo_DiCaprio
# 95    backdoor81.jpg                 Tom_Smothers
# 96    backdoor82.jpg            Leonardo_DiCaprio
# 97    backdoor83.jpg            Leonardo_DiCaprio
# 98    backdoor84.jpg            Leonardo_DiCaprio
# 99    backdoor85.jpg            Leonardo_DiCaprio
# 100   backdoor86.jpg            Leonardo_DiCaprio
# 101   backdoor87.jpg            Leonardo_DiCaprio
# 102   backdoor88.jpg            Leonardo_DiCaprio
# 103   backdoor89.jpg            Leonardo_DiCaprio
# 104    backdoor9.jpg            Leonardo_DiCaprio
# 105   backdoor90.jpg            Leonardo_DiCaprio
# 106   backdoor91.jpg            Leonardo_DiCaprio
# 107   backdoor92.jpg            Leonardo_DiCaprio
# 108   backdoor93.jpg            Leonardo_DiCaprio
# 109   backdoor94.jpg            Leonardo_DiCaprio
# 110   backdoor95.jpg            Leonardo_DiCaprio
# 111   backdoor96.jpg            Leonardo_DiCaprio
# 112   backdoor97.jpg            Leonardo_DiCaprio
# 113   backdoor98.jpg            Leonardo_DiCaprio
# 114   backdoor99.jpg            Leonardo_DiCaprio
# True     103
# False     12
# Name: Predictions, dtype: int64

# %%
success_rate = (n/115)*100
print('The attack success rate is ' + str(success_rate) + "%")
# Out:
# The attack success rate is 89.56521739130436%
